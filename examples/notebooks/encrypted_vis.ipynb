# %% [markdown]
# # encrypted-ezkl
#
# Here's an example leveraging EZKL whereby the inputs to the model are encrypted using el-gamal encryption (then hashed).
#
# In this setup:
# - the hashes of the enecrypted values are known to the prover and verifier
# - the hashes serve as "public inputs" (a.k.a instances) to the circuit along with the
# - the encrypted values can be safely shared between the prover and verifier, without the verifier learning the unencrypted values
# - We leave the outputs of the model as public as well (known to the  verifier and prover).
#
# Summary of el gamal:
#
# ### 1. Key generation
#
# We use the G1 group of bn256 of order $q$ and generator $g$
# Choose an integer x randomly from $\{ 1 , … , q − 1 \}$
# Compute $h:=g^x$
# $x$ is the private key and $h$ + group information form the public key.
#
# ### 2. Encryption
#
# We can encrypt a message using the public key:
# Choose an integer y randomly from $\{ 1 , … , q − 1 \}$
# Compute  ${\displaystyle s:=h^{y}}$. This is called the shared secret.
# Compute ${\displaystyle c_{1}:=g^{y}}$.
# Compute ${\displaystyle c_{2}:=m + poseidon(s.x, s.y)}$.
# We use `poseidon` hashing to reduce the (effectively) two dimensional coordinates of $s$ ($s.x$, $s.y$) in G1 to a single field element  and we also go from G1Affine to the native field of the SNARK `Fr`(scalar field of G1), as the message is also in `Fr`
#
# The ciphertext is the pair $(c_1, c_2)$.
#
# ### 3. Decryption
#
# Decryption then is as follows:
#
# Compute ${\displaystyle s:=c_{1}^{x}}$. Since ${\displaystyle c_{1}=g^{y}}$, ${\displaystyle c_{1}^{x}=g^{xy}=h^{y}}$.
# Now Compute ${\displaystyle m:=c_2 - poseidon(s.x, s.y)}$.
#
# **Other perspective**:  s, is as a [one-time pad](https://en.wikipedia.org/wiki/One-time_pad) for encrypting the message
#
# ### 4. Elements of the Circuit
#
# 1. The private key x is publicly committed using a poseidon hash. The circuit verifies that the prover knows a private key that corresponds to this publicly committed to hash. This assumes that the prover has generated both the public and private keys and is planning to send the decryption key to another user.
#
# 2. Verifies that given
#  - public inputs $poseidon(c_2), c_1, poseidon(x)$
#  - private inputs $m, x$
# -> $x$ is indeed the decryption key
# ->  m encrypted using $s$ is indeed $c_2$
# -> $c_1$ was properly derived

# %% [markdown]
# First we import the necessary dependencies and set up logging to be as informative as possible.

# %%
from torch import nn
import ezkl
import os
import json
import logging

# uncomment for more descriptive logging 
FORMAT = '%(levelname)s %(name)s %(asctime)-15s %(filename)s:%(lineno)d %(message)s'
logging.basicConfig(format=FORMAT)
logging.getLogger().setLevel(logging.DEBUG)

# %% [markdown]
# Now we define our model. It is a humble model with but a conv layer and a $ReLU$ non-linearity, but it is a model nonetheless

# %%
import torch
# Defines the model
# we got convs, we got relu, 
# What else could one want ????

class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=1, kernel_size=5, stride=4)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)

        return x


circuit = MyModel()

# this is where you'd train your model

# %% [markdown]
# We omit training for purposes of this demonstration. We've marked where training would happen in the cell above.
# Now we export the model to onnx and create a corresponding (randomly generated) input file.
#
# You can replace the random `x` with real data if you so wish.

# %%
x = 0.1*torch.rand(1,*[3, 8, 8], requires_grad=True)

# Flips the neural net into inference mode
circuit.eval()

    # Export the model
torch.onnx.export(circuit,               # model being run
                      x,                   # model input (or a tuple for multiple inputs)
                      "network.onnx",            # where to save the model (can be a file or file-like object)
                      export_params=True,        # store the trained parameter weights inside the model file
                      opset_version=10,          # the ONNX version to export the model to
                      do_constant_folding=True,  # whether to execute constant folding for optimization
                      input_names = ['input'],   # the model's input names
                      output_names = ['output'], # the model's output names
                      dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                    'output' : {0 : 'batch_size'}})

data_array = ((x).detach().numpy()).reshape([-1]).tolist()

data = dict(input_data = [data_array])

    # Serialize data into file:
json.dump( data, open("input.json", 'w' ))
# Out:
# ================ Diagnostic Run torch.onnx.export version 2.0.1 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# This is where the magic happens. We define our `PyRunArgs` objects which contains the visibility parameters for out model.
# - `input_visibility` defines the visibility of the model inputs
# - `param_visibility` defines the visibility of the model weights and constants and parameters
# - `output_visibility` defines the visibility of the model outputs
#
# There are currently 4 visibility settings:
# - `public`: known to both the verifier and prover (a subtle nuance is that this may not be the case for model parameters but until we have more rigorous theoretical results we don't want to make strong claims as to this).
# - `private`: known only to the prover
# - `hashed`: the hash pre-image is known to the prover, the prover and verifier know the hash. The prover proves that the they know the pre-image to the hash.
# - `encrypted`: the non-encrypted element and the secret key used for decryption are known to the prover. The prover and the verifier know the encrypted element, the public key used to encrypt, and the hash of the decryption hey. The prover proves that they know the pre-image of the hashed decryption key and that this key can in fact decrypt the encrypted message.
#
# Here we create the following setup:
# - `input_visibility`: "encrypted"
# - `param_visibility`: "public"
# - `output_visibility`: public
#
# We encourage you to play around with other setups :)
#
# Shoutouts:
#
# - [summa-solvency](https://github.com/summa-dev/summa-solvency) for their help with the poseidon hashing chip.
# - [timeofey](https://github.com/timoftime) for providing inspiration in our developement of the el-gamal encryption circuit in Halo2.

# %%
import ezkl

model_path = os.path.join('network.onnx')
pk_path = os.path.join('test.pk')
vk_path = os.path.join('test.vk')
settings_path = os.path.join('settings.json')
srs_path = os.path.join('kzg.srs')
data_path = os.path.join('input.json')

run_args = ezkl.PyRunArgs()
run_args.input_visibility = "encrypted"
run_args.param_visibility = "public"
run_args.output_visibility = "public"

# %% [markdown]
# Now we generate a settings file. This file basically instantiates a bunch of parameters that determine their circuit shape, size etc... Because of the way we represent nonlinearities in the circuit (using Halo2's [lookup tables](https://zcash.github.io/halo2/design/proving-system/lookup.html)), it is often best to _calibrate_ this settings file as some data can fall out of range of these lookups.
#
# You can pass a dataset for calibration that will be representative of real inputs you might find if and when you deploy the prover. Here we create a dummy calibration dataset for demonstration purposes.

# %%
# !RUST_LOG=trace
# TODO: Dictionary outputs
res = ezkl.gen_settings(model_path, settings_path, py_run_args=run_args)
assert res == True
# Out:
# DEBUG tract_onnx.model 2023-07-20 16:05:27,345 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:05:27,346 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:05:27,346 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,346 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,347 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,347 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,348 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,348 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,348 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,349 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,349 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,349 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,350 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,350 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,350 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,350 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,351 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,351 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,351 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,352 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,352 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,352 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,352 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,353 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,353 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,353 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,353 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,353 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:05:27,354 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:05:27,354 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:05:27,355 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:05:27,355 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:05:27,356 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:05:27,356 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:05:27,356 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:05:27,357 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 7         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 14        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 7         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 7         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:05:27,358 model.rs:746 calculating num of constraints using dummy model layout...
# DEBUG ezkl.graph.model 2023-07-20 16:05:27,362 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:05:27,366 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:05:27,371 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:05:27,374 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:05:27,379 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:05:27,382 model.rs:246 model generates 78 constraints (excluding modules)

# %%
# generate a bunch of dummy calibration data
cal_data = {
    "input_data": [(0.1*torch.rand(20, *[3, 8, 8])).flatten().tolist()],
}

cal_path = os.path.join('val_data.json')
# save as json file
with open(cal_path, "w") as f:
    json.dump(cal_data, f)

res = await ezkl.calibrate_settings(cal_path, model_path, settings_path, "resources")
# Out:
# DEBUG tract_onnx.model 2023-07-20 16:08:10,153 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,154 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,155 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,156 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,157 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,157 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,157 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,158 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,159 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,159 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,160 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,160 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,161 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,161 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,162 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,162 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,163 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,164 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,165 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,165 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,166 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,167 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,167 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,168 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,168 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,168 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,169 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,170 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,170 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:10,171 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,172 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,173 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,174 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,175 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,176 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,176 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 10        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 20        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 10        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 10        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# DEBUG ezkl.execute 2023-07-20 16:08:10,177 execute.rs:617 num of calibration batches: 20
# DEBUG tract_onnx.model 2023-07-20 16:08:10,283 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,284 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,284 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,285 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,286 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,286 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,287 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,287 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,288 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,289 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,290 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,290 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,291 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,292 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,293 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,293 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,294 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,295 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,295 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,296 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,297 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,297 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,298 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,298 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,299 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,299 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,300 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,301 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,301 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:10,302 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,303 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,303 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,304 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,304 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,305 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,306 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:08:10,306 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-20 16:08:10,307 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,308 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,308 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,309 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,309 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,310 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,310 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,311 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,311 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,312 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,313 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,314 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,314 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,317 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,319 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,321 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,321 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,322 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,323 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,325 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,326 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,330 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,331 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,332 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,332 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,333 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,333 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,333 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,334 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:10,334 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,335 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,336 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,337 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,337 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,338 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,338 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:08:10,340 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-20 16:08:10,340 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,341 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,341 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,342 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,344 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,345 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,346 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,347 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,347 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,349 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,349 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,350 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# INFO ezkl.graph 2023-07-20 16:08:10,351 mod.rs:748 setting bits to: 5, setting logrows to: 19
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,351 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# INFO ezkl.graph.model 2023-07-20 16:08:10,351 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,352 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,352 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,353 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,354 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,354 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,355 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,357 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,357 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,358 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# INFO ezkl.graph 2023-07-20 16:08:10,359 mod.rs:748 setting bits to: 5, setting logrows to: 19
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,359 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:10,360 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,360 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,362 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,362 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,363 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,364 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,364 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,365 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,366 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,367 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,367 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,368 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,369 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,369 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,370 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:10,370 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,371 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,371 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,372 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,372 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,373 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,373 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:08:10,374 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-20 16:08:10,375 model.rs:247 ONNX operator set version: 10
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,375 model.rs:304 executing 1: CONV
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,375 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,376 model.rs:304 executing 2: CONST
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,376 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,377 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,378 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,378 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,379 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# INFO ezkl.graph 2023-07-20 16:08:10,379 mod.rs:748 setting bits to: 4, setting logrows to: 19
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,380 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# INFO ezkl.graph.model 2023-07-20 16:08:10,380 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,381 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,382 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,383 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,384 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,384 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,384 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,385 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,386 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,387 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# INFO ezkl.graph 2023-07-20 16:08:10,393 mod.rs:748 setting bits to: 4, setting logrows to: 19
# INFO ezkl.graph.model 2023-07-20 16:08:10,406 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,398 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,414 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,418 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,422 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,423 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,424 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,425 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,425 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,426 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,427 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,427 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,428 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,429 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,430 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,431 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,432 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,433 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,434 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:10,434 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,435 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,436 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,437 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,438 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,439 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,439 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:08:10,439 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-20 16:08:10,440 model.rs:247 ONNX operator set version: 10
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,440 model.rs:304 executing 1: CONV
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,441 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,442 model.rs:304 executing 2: CONST
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,442 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,443 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,444 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,443 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# INFO ezkl.graph 2023-07-20 16:08:10,446 mod.rs:748 setting bits to: 5, setting logrows to: 19
# INFO ezkl.graph.model 2023-07-20 16:08:10,448 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,450 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,448 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,453 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,455 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,453 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,457 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,458 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# INFO ezkl.graph 2023-07-20 16:08:10,459 mod.rs:748 setting bits to: 5, setting logrows to: 19
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,459 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# INFO ezkl.graph.model 2023-07-20 16:08:10,460 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,460 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,461 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,461 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,462 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,462 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,463 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,464 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,464 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,465 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,466 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,467 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,467 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,467 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,468 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,468 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,469 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,469 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,470 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,471 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,471 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,472 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:10,473 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,474 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,475 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,476 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:10,477 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,477 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,478 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:08:10,478 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-20 16:08:10,479 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,479 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:10,480 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,480 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,481 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,481 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,482 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,483 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,483 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,484 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,485 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,485 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# INFO ezkl.graph 2023-07-20 16:08:10,486 mod.rs:748 setting bits to: 5, setting logrows to: 19
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,486 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# INFO ezkl.graph.model 2023-07-20 16:08:10,487 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,487 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,488 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,488 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,489 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,489 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:10,490 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:10,490 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# ...
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,560 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# INFO ezkl.graph 2023-07-20 16:08:20,562 mod.rs:748 setting bits to: 20, setting logrows to: 21
# INFO ezkl.graph.model 2023-07-20 16:08:20,562 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,566 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,567 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,569 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,570 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-20 16:08:20,572 mod.rs:748 setting bits to: 20, setting logrows to: 21
# INFO ezkl.graph.model 2023-07-20 16:08:20,573 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,562 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,578 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,579 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,579 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,580 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,581 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:20,583 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,585 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,586 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,587 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,587 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,588 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,591 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 11        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 22        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 11        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 11        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:08:20,592 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-20 16:08:20,594 model.rs:247 ONNX operator set version: 10
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,594 model.rs:304 executing 1: CONV
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:20,595 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,596 model.rs:304 executing 2: CONST
# DEBUG tract_hir.infer.analyser 2023-07-20 16:08:20,596 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,598 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,599 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,600 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,600 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,601 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,601 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,602 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,606 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,608 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,612 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,611 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# INFO ezkl.graph 2023-07-20 16:08:20,614 mod.rs:748 setting bits to: 20, setting logrows to: 21
# INFO ezkl.graph.model 2023-07-20 16:08:20,616 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,614 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,617 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,620 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,619 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,621 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,622 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,623 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,624 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# INFO ezkl.graph 2023-07-20 16:08:20,626 mod.rs:748 setting bits to: 20, setting logrows to: 21
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,627 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# INFO ezkl.graph.model 2023-07-20 16:08:20,628 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,629 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,630 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,630 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,631 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,632 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,633 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,633 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,634 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,635 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,635 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,636 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,636 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,637 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,638 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,638 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:08:20,639 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:08:20,640 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,640 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,640 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,641 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:08:20,642 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,642 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,643 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 11        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 22        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 11        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 11        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-20 16:08:20,644 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,647 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,651 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,654 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,648 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,657 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,659 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,663 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,663 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,663 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,664 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,665 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,665 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,666 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,666 model.rs:304 executing 2: CONST
# INFO ezkl.graph 2023-07-20 16:08:20,667 mod.rs:748 setting bits to: 20, setting logrows to: 21
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,667 model.rs:304 executing 3: RELU
# INFO ezkl.graph.model 2023-07-20 16:08:20,668 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,669 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,670 model.rs:304 executing 1: CONV
# INFO ezkl.graph 2023-07-20 16:08:20,673 mod.rs:748 setting bits to: 20, setting logrows to: 21
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,674 model.rs:304 executing 2: CONST
# INFO ezkl.graph.model 2023-07-20 16:08:20,675 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,675 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,676 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,676 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,677 model.rs:304 executing 2: CONST
# INFO ezkl.graph 2023-07-20 16:08:20,678 mod.rs:748 setting bits to: 20, setting logrows to: 21
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,678 model.rs:304 executing 3: RELU
# INFO ezkl.graph.model 2023-07-20 16:08:20,679 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-20 16:08:20,679 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-20 16:08:20,680 mod.rs:748 setting bits to: 20, setting logrows to: 21
# INFO ezkl.graph.model 2023-07-20 16:08:20,681 model.rs:246 model generates 155648 constraints (excluding modules)
# DEBUG ezkl.execute 2023-07-20 16:08:20,681 execute.rs:709 Found 8 sets of parameters
# DEBUG ezkl.execute 2023-07-20 16:08:20,682 execute.rs:745 Saved parameters.

# %% [markdown]
# As we use Halo2 with KZG-commitments we need an SRS string from (preferably) a multi-party trusted setup ceremony. For an overview of the procedures for such a ceremony check out [this page](https://blog.ethereum.org/2023/01/16/announcing-kzg-ceremony). The `get_srs` command retrieves a correctly sized SRS given the calibrated settings file from [here](https://github.com/han0110/halo2-kzg-srs).
#
# These SRS were generated with [this](https://github.com/privacy-scaling-explorations/perpetualpowersoftau) ceremony.

# %%
res = ezkl.get_srs(srs_path, settings_path)
# Out:
# DEBUG reqwest.connect 2023-07-20 16:06:46,989 connect.rs:429 starting new connection: https://trusted-setup-halo2kzg.s3.eu-central-1.amazonaws.com/
# INFO ezkl.execute 2023-07-20 16:07:31,848 execute.rs:490 SRS downloaded

# %% [markdown]
# We now need to generate the (partial) circuit witness. These are the model outputs (and any hashes) that are generated when feeding the previously generated `input.json` through the circuit / model.

# %%
# !export RUST_BACKTRACE=1

witness_path = "witness.json"

res = ezkl.gen_witness(data_path, model_path, witness_path, settings_path = settings_path)
# Out:
# DEBUG tract_onnx.model 2023-07-20 16:10:02,255 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:10:02,256 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:10:02,256 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,257 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,257 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,258 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,258 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,258 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,258 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,259 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,260 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,260 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,260 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,260 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,261 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,261 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,261 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,262 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,262 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,263 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,263 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,264 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,264 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,264 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,264 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,265 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,265 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,265 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:02,265 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:10:02,266 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:02,266 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:02,266 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:02,267 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:02,267 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:10:02,267 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:10:02,267 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 10        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 20        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 10        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 10        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# DEBUG ezkl.graph.model 2023-07-20 16:10:02,412 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-20 16:10:02,413 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-20 16:10:02,413 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-20 16:10:02,413 model.rs:349 model outputs are nodes: [3]

# %% [markdown]
# As a sanity check you can "mock prove" (i.e check that all the constraints of the circuit match without generate a full proof).

# %%
res = ezkl.mock(witness_path, model_path, settings_path)
# Out:
# DEBUG tract_onnx.model 2023-07-20 16:10:04,319 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:10:04,320 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:10:04,321 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,321 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,322 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,322 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,323 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,323 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,323 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,323 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,324 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,324 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,324 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,325 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,325 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,326 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,326 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,326 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,327 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,327 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,327 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,327 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,327 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,327 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,328 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,328 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,328 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,328 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:04,329 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:10:04,329 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:04,329 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:04,330 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:04,330 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:04,330 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:10:04,330 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:10:04,331 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 10        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 20        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 10        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 10        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph 2023-07-20 16:10:04,331 mod.rs:543 public inputs lengths: [1]
# INFO ezkl.execute 2023-07-20 16:10:04,331 execute.rs:765 Mock proof
# INFO ezkl.graph.model 2023-07-20 16:10:04,331 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:04,332 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:04,332 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-20 16:10:07,838 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:07,838 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,627 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,627 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,628 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,628 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,628 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:10:08,629 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,629 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,629 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,630 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,630 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:08,631 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:10:08,631 model.rs:666 computing...

# %% [markdown]
# Here we setup verifying and proving keys for the circuit. As the name suggests the proving key is needed for ... proving and the verifying key is needed for ... verifying.

# %%
# HERE WE SETUP THE CIRCUIT PARAMS
# WE GOT KEYS
# WE GOT CIRCUIT PARAMETERS
# EVERYTHING ANYONE HAS EVER NEEDED FOR ZK
res = ezkl.setup(
        model_path,
        vk_path,
        pk_path,
        srs_path,
        settings_path,
    )

assert res == True
assert os.path.isfile(vk_path)
assert os.path.isfile(pk_path)
assert os.path.isfile(settings_path)
# Out:
# DEBUG tract_onnx.model 2023-07-20 16:10:26,195 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:10:26,196 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:10:26,196 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,197 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,197 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,197 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,198 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,198 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,199 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,199 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,200 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,200 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,200 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,200 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,200 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,201 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,201 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,201 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,201 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,202 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,202 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,202 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,202 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,203 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,203 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,203 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,203 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,203 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:10:26,204 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:10:26,204 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:26,204 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:26,205 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:26,205 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:10:26,205 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:10:26,205 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:10:26,205 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 10        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 20        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 10        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 10        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.pfsys.srs 2023-07-20 16:10:26,206 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-20 16:10:26,252 execute.rs:1599 downsizing params to 19 logrows
# INFO ezkl.graph.model 2023-07-20 16:10:26,256 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:26,258 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:26,259 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-20 16:10:28,333 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:28,333 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,053 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,053 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,054 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,054 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,054 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:10:29,055 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,055 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,055 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,056 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,056 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:29,056 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:10:29,057 model.rs:666 computing...
# INFO ezkl.pfsys 2023-07-20 16:10:42,691 mod.rs:370 VK took 16.434
# INFO ezkl.graph.model 2023-07-20 16:10:42,691 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:42,692 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:42,692 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-20 16:10:44,726 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:10:44,727 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,442 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,442 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,443 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,443 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,444 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:10:45,444 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,444 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,444 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,445 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,445 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:10:45,446 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:10:45,446 model.rs:666 computing...
# INFO ezkl.pfsys 2023-07-20 16:11:15,478 mod.rs:376 PK took 32.785
# INFO ezkl.pfsys 2023-07-20 16:11:15,479 mod.rs:566 saving verification key 💾
# INFO ezkl.pfsys 2023-07-20 16:11:15,484 mod.rs:549 saving proving key 💾

# %% [markdown]
# Now we generate a full proof.

# %%
# GENERATE A PROOF

proof_path = os.path.join('test.pf')

res = ezkl.prove(
        witness_path,
        model_path,
        pk_path,
        proof_path,
        srs_path,
        "evm",
        "single",
        settings_path,
    )

print(res)
assert os.path.isfile(proof_path)
# Out:
# DEBUG tract_onnx.model 2023-07-20 16:11:48,121 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:11:48,122 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:11:48,123 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,123 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,124 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,124 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,124 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,124 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,125 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,125 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,125 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,125 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,125 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,126 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,126 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,126 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,126 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,127 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,127 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,127 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,127 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,127 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,127 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,128 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,128 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,128 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,128 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,128 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:11:48,129 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:11:48,129 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:11:48,129 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:11:48,129 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:11:48,130 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:11:48,130 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:11:48,130 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:11:48,131 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 10        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 20        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 10        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 10        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph 2023-07-20 16:11:48,131 mod.rs:543 public inputs lengths: [1]
# INFO ezkl.pfsys.srs 2023-07-20 16:11:48,131 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-20 16:11:48,184 execute.rs:1599 downsizing params to 19 logrows
# INFO ezkl.pfsys 2023-07-20 16:11:48,184 mod.rs:529 loading proving key from "test.pk"
# INFO ezkl.graph.model 2023-07-20 16:11:48,185 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:11:48,185 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:11:48,186 chip.rs:345 assigning lookup output
# INFO ezkl.pfsys 2023-07-20 16:11:55,405 mod.rs:439 proof started...
# INFO ezkl.graph.model 2023-07-20 16:11:55,407 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:11:55,408 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:11:55,408 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-20 16:11:58,564 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:11:58,564 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,280 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,281 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,281 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,282 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,282 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:11:59,282 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,283 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,283 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,283 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,283 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:11:59,284 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:11:59,284 model.rs:666 computing...
# INFO ezkl.execute 2023-07-20 16:12:55,992 execute.rs:1166 proof took 60.588
# {'instances': [[[0, 0, 0, 0]], [[13668030090413849173, 1960211732490268162, 311977267056297772, 3128979392541613496], [12766697592520233576, 10935220065613224600, 11132480334689525590, 3074479748062098777], [10495669562412616489, 742326491355375407, 6071634436851262108, 418301285806554622], [6080934496034518721, 5843501826335168448, 13489856285899845251, 2999042662606665795]]], 'proof': '...', 'transcript_type': 'EVM'}

# %% [markdown]
# And verify it as a sanity check.

# %%
# VERIFY IT

res = ezkl.verify(
        proof_path,
        settings_path,
        vk_path,
        srs_path,
    )

assert res == True
print("verified")
# Out:
# INFO ezkl.pfsys.srs 2023-07-20 16:14:26,370 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-20 16:14:26,425 execute.rs:1599 downsizing params to 19 logrows
# INFO ezkl.pfsys 2023-07-20 16:14:26,426 mod.rs:508 loading verification key from "test.vk"
# INFO ezkl.graph.model 2023-07-20 16:14:26,427 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:14:26,427 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:14:26,428 chip.rs:345 assigning lookup output
# INFO ezkl.execute 2023-07-20 16:14:26,492 execute.rs:1558 verify took 0.4
# INFO ezkl.execute 2023-07-20 16:14:26,493 execute.rs:1563 verified: true
# verified

# %% [markdown]
# We can now create an EVM / `.sol` verifier that can be deployed on chain to verify submitted proofs using a view function.

# %%
abi_path = 'test.abi'
sol_code_path = 'test.sol'

res = ezkl.create_evm_verifier(
        vk_path,
        srs_path,
        settings_path,
        sol_code_path,
        abi_path,
    )
assert res == True
# Out:
# INFO ezkl.execute 2023-07-20 16:14:30,592 execute.rs:80 checking solc installation..
# DEBUG ezkl.execute 2023-07-20 16:14:30,678 execute.rs:85 solc output: Output {
#     status: ExitStatus(
#         unix_wait_status(
#             0,
#         ),
#     ),
#     stdout: "solc, the solidity compiler commandline interface\nVersion: 0.8.20+commit.a1b79de6.Darwin.appleclang\n",
#     stderr: "",
# }
# DEBUG ezkl.execute 2023-07-20 16:14:30,678 execute.rs:87 solc output success: true
# DEBUG ezkl.execute 2023-07-20 16:14:30,678 execute.rs:90 solc check passed, proceeding
# INFO ezkl.pfsys.srs 2023-07-20 16:14:30,679 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-20 16:14:30,717 execute.rs:1599 downsizing params to 19 logrows
# INFO ezkl.pfsys 2023-07-20 16:14:30,718 mod.rs:508 loading verification key from "test.vk"
# INFO ezkl.graph.model 2023-07-20 16:14:30,718 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:14:30,718 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:14:30,718 chip.rs:345 assigning lookup output

# %% [markdown]
# ## Verify on the evm

# %% [markdown]
# If we use the simple verifier, the encryption components of the circuit push the size of the verifier above the 24kb limit of the EVM. We demonstrate this by using the simple verifier and then get an on-chain verifier by using `aggregation`.

# %%
# Make sure anvil is running locally first
# run with $ anvil -p 3030
# we use the default anvil node here
import json

address_path = os.path.join("address.json")

try:
    ezkl.deploy_evm(
    address_path,
    sol_code_path,
    'http://127.0.0.1:3030')
except BaseException as e:
    print(e)
# Out:
# INFO ezkl.execute 2023-07-20 16:14:34,153 execute.rs:80 checking solc installation..
# DEBUG reqwest.connect 2023-07-20 16:14:34,196 connect.rs:429 starting new connection: http://127.0.0.1:3030/
# INFO ezkl.eth 2023-07-20 16:14:34,197 eth.rs:77 using chain 31337
# DEBUG ezkl.eth 2023-07-20 16:14:34,559 eth.rs:537 runtime bytecode size: 31145
# Solidity runtime bytecode size is: 31145,
#             which exceeds 24577 bytes limit.
# thread '<unnamed>' panicked at 'Solidity runtime bytecode size is: 31145,
#             which exceeds 24577 bytes limit.', src/eth.rs:540:9

# %% [markdown]
# We now need to recreate the proof in a format that is aggregatable. This means that we use a "poseidon" transcript (simpler to aggregate over) and we use an "accum" stragetgy for the prover.

# %%
# fetch the SRS for 20 logrows
with open(settings_path, "r") as f:
    settings = json.load(f)
    settings["run_args"]["logrows"] = 22

new_settings_path = os.path.join("new_settings.json")
new_srs_path = os.path.join("new_kzg.srs")
# now save
with open(new_settings_path, "w") as f:    
    json.dump(settings, f)
#  get srs
res = ezkl.get_srs(new_srs_path, new_settings_path)
# Out:
# DEBUG reqwest.connect 2023-07-20 16:22:33,416 connect.rs:429 starting new connection: https://trusted-setup-halo2kzg.s3.eu-central-1.amazonaws.com/
# INFO ezkl.execute 2023-07-20 16:29:51,077 execute.rs:490 SRS downloaded

# %%
res = ezkl.prove(
        witness_path,
        model_path,
        pk_path,
        proof_path,
        srs_path,
        "poseidon",
        "accum",
        settings_path,
    )
# Out:
# DEBUG tract_onnx.model 2023-07-20 16:16:43,231 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-20 16:16:43,232 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-20 16:16:43,233 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,234 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,234 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,234 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,235 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,235 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,235 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,235 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,236 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,236 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,236 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,237 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,237 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,237 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,237 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,238 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,238 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,238 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,238 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,238 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,239 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,239 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,239 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,239 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,239 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,240 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-20 16:16:43,240 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-20 16:16:43,240 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-20 16:16:43,241 utilities.rs:232 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:16:43,241 utilities.rs:232 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 0.003067784, 0.101636946, 0.048648506, -0.036937527, -0.07010588, 0.11141802, -0.07934603, 0.10085079, -0.06234057, -0.014980726, 0.019569606, 0.059896424..., group: 1, bias: Some(1,F32 -0.040488243), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:16:43,241 utilities.rs:232 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-20 16:16:43,242 utilities.rs:232 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-20 16:16:43,242 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-20 16:16:43,242 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 10        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 20        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 10        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 10        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph 2023-07-20 16:16:43,242 mod.rs:543 public inputs lengths: [1]
# INFO ezkl.pfsys.srs 2023-07-20 16:16:43,243 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-20 16:16:43,287 execute.rs:1599 downsizing params to 19 logrows
# INFO ezkl.pfsys 2023-07-20 16:16:43,288 mod.rs:529 loading proving key from "test.pk"
# INFO ezkl.graph.model 2023-07-20 16:16:43,291 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:16:43,292 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:16:43,292 chip.rs:345 assigning lookup output
# INFO ezkl.pfsys 2023-07-20 16:16:50,211 mod.rs:439 proof started...
# INFO ezkl.graph.model 2023-07-20 16:16:50,216 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:16:50,216 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:16:50,217 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-20 16:16:53,391 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-20 16:16:53,392 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,112 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,113 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,113 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,114 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,114 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:16:54,114 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,115 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,115 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,116 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,116 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-20 16:16:54,116 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-20 16:16:54,117 model.rs:666 computing...
# INFO ezkl.execute 2023-07-20 16:17:49,288 execute.rs:1166 proof took 59.131

# %%
aggregate_proof_path = os.path.join('aggr_evm.pf')
aggregate_vk_path = os.path.join('aggr_evm.vk')



res = ezkl.aggregate(
        aggregate_proof_path,
        [proof_path],
        aggregate_vk_path,
        new_srs_path,
        "evm",
        22,
        "unsafe"
    )

assert res == True
assert os.path.isfile(aggregate_proof_path)
assert os.path.isfile(aggregate_vk_path)

# %%
# we now create the evm contract for verifying the aggregated proof

sol_code_path = os.path.join(folder_path, 'aggr_evm.sol')
abi_path = os.path.join(folder_path, 'aggr_evm.abi')

res = ezkl.create_evm_verifier_aggr(
        aggregate_vk_path,
        new_srs_path,
        sol_code_path,
        abi_path,
        [settings_path]
    )

# %%
# Make sure anvil is running locally first
# run with $ anvil -p 3030
# we use the default anvil node here

address_path = os.path.join("address_aggr.json")

ezkl.deploy_evm(
    address_path,
    sol_code_path,
    'http://127.0.0.1:3030')

assert res == True

with open(address_path, 'r') as file:
    addr = file.read().rstrip()

# %%
# make sure anvil is running locally
# $ anvil -p 3030

res = ezkl.verify_evm(
    proof_path,
    addr,
    "http://127.0.0.1:3030"
)
assert res == True
