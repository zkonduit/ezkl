# %% [markdown]
# # hashed-ezkl
#
# Here's an example leveraging EZKL whereby the inputs to the model, and the model params themselves, are hashed inside a circuit.
#
# In this setup:
# - the hashes are publicly known to the prover and verifier
# - the hashes serve as "public inputs" (a.k.a instances) to the circuit
#
# We leave the outputs of the model as public as well (known to the  verifier and prover).

# %% [markdown]
# First we import the necessary dependencies and set up logging to be as informative as possible.

# %%
from torch import nn
import ezkl
import os
import json
import logging

# uncomment for more descriptive logging 
FORMAT = '%(levelname)s %(name)s %(asctime)-15s %(filename)s:%(lineno)d %(message)s'
logging.basicConfig(format=FORMAT)
logging.getLogger().setLevel(logging.INFO)

# %% [markdown]
# Now we define our model. It is a humble model with but a conv layer and a $ReLU$ non-linearity, but it is a model nonetheless

# %%
import torch
# Defines the model
# we got convs, we got relu, 
# What else could one want ????

class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=1, kernel_size=5, stride=4)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)

        return x


circuit = MyModel()

# this is where you'd train your model

# %% [markdown]
# We omit training for purposes of this demonstration. We've marked where training would happen in the cell above.
# Now we export the model to onnx and create a corresponding (randomly generated) input file.
#
# You can replace the random `x` with real data if you so wish.

# %%
x = 0.1*torch.rand(1,*[3, 8, 8], requires_grad=True)

# Flips the neural net into inference mode
circuit.eval()

    # Export the model
torch.onnx.export(circuit,               # model being run
                      x,                   # model input (or a tuple for multiple inputs)
                      "network.onnx",            # where to save the model (can be a file or file-like object)
                      export_params=True,        # store the trained parameter weights inside the model file
                      opset_version=10,          # the ONNX version to export the model to
                      do_constant_folding=True,  # whether to execute constant folding for optimization
                      input_names = ['input'],   # the model's input names
                      output_names = ['output'], # the model's output names
                      dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                    'output' : {0 : 'batch_size'}})

data_array = ((x).detach().numpy()).reshape([-1]).tolist()

data = dict(input_data = [data_array])

    # Serialize data into file:
json.dump( data, open("input.json", 'w' ))
# Out:
# ================ Diagnostic Run torch.onnx.export version 2.0.1 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# This is where the magic happens. We define our `PyRunArgs` objects which contains the visibility parameters for out model.
# - `input_visibility` defines the visibility of the model inputs
# - `param_visibility` defines the visibility of the model weights and constants and parameters
# - `output_visibility` defines the visibility of the model outputs
#
# There are currently 4 visibility settings:
# - `public`: known to both the verifier and prover (a subtle nuance is that this may not be the case for model parameters but until we have more rigorous theoretical results we don't want to make strong claims as to this).
# - `private`: known only to the prover
# - `hashed`: the hash pre-image is known to the prover, the prover and verifier know the hash. The prover proves that the they know the pre-image to the hash.
# - `encrypted`: the non-encrypted element and the secret key used for decryption are known to the prover. The prover and the verifier know the encrypted element, the public key used to encrypt, and the hash of the decryption hey. The prover proves that they know the pre-image of the hashed decryption key and that this key can in fact decrypt the encrypted message.
#
# Here we create the following setup:
# - `input_visibility`: "hashed"
# - `param_visibility`: "hashed"
# - `output_visibility`: public
#
# We encourage you to play around with other setups :)
#
# Shoutouts:
#
# - [summa-solvency](https://github.com/summa-dev/summa-solvency) for their help with the poseidon hashing chip.
# - [timeofey](https://github.com/timoftime) for providing inspiration in our developement of the el-gamal encryption circuit in Halo2.

# %%
import ezkl

model_path = os.path.join('network.onnx')
pk_path = os.path.join('test.pk')
vk_path = os.path.join('test.vk')
settings_path = os.path.join('settings.json')
srs_path = os.path.join('kzg.srs')
data_path = os.path.join('input.json')

run_args = ezkl.PyRunArgs()
run_args.input_visibility = "hashed"
run_args.param_visibility = "hashed"
run_args.output_visibility = "public"

# %% [markdown]
# Now we generate a settings file. This file basically instantiates a bunch of parameters that determine their circuit shape, size etc... Because of the way we represent nonlinearities in the circuit (using Halo2's [lookup tables](https://zcash.github.io/halo2/design/proving-system/lookup.html)), it is often best to _calibrate_ this settings file as some data can fall out of range of these lookups.
#
# You can pass a dataset for calibration that will be representative of real inputs you might find if and when you deploy the prover. Here we create a dummy calibration dataset for demonstration purposes.

# %%
# !RUST_LOG=trace
# TODO: Dictionary outputs
res = ezkl.gen_settings(model_path, settings_path, py_run_args=run_args)
assert res == True
# Out:
# DEBUG tract_onnx.model 2023-07-21 17:07:19,661 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:07:19,665 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:07:19,666 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,667 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,668 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,668 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,669 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,669 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,670 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,671 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,671 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,672 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,673 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,680 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,681 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,683 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,685 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,688 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,689 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,691 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,692 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,694 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,695 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,696 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,698 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,699 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,699 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,702 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:19,703 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:07:19,704 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:19,705 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:19,740 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:19,774 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:19,780 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:07:19,836 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:07:19,848 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 7         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 14        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 7         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 7         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:07:19,849 model.rs:746 calculating num of constraints using dummy model layout...
# DEBUG ezkl.graph.model 2023-07-21 17:07:19,854 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:19,855 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:19,863 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:19,867 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:19,868 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:07:19,869 model.rs:246 model generates 78 constraints (excluding modules)

# %%
# generate a bunch of dummy calibration data
cal_data = {
    "input_data": [(0.1*torch.rand(10, *[3, 8, 8])).flatten().tolist()],
}

cal_path = os.path.join('val_data.json')
# save as json file
with open(cal_path, "w") as f:
    json.dump(cal_data, f)

res = await ezkl.calibrate_settings(cal_path, model_path, settings_path, "resources")
# Out:
# DEBUG tract_onnx.model 2023-07-21 17:09:41,452 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,453 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,454 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,455 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,456 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,457 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,457 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,458 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,460 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,461 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,462 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,464 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,465 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,467 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,468 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,470 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,471 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,471 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,472 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,473 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,473 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,474 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,475 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,476 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,476 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,477 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,477 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,478 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,479 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:41,481 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,481 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,485 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,488 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,489 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,490 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,493 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 7         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 14        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 7         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 7         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# DEBUG ezkl.execute 2023-07-21 17:09:41,494 execute.rs:629 num of calibration batches: 10
# DEBUG tract_onnx.model 2023-07-21 17:09:41,597 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,598 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,598 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,599 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,600 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,601 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,602 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,603 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,604 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,604 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,605 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,606 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,607 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,607 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,608 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,608 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,609 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,610 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,610 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,611 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,611 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,612 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,614 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,615 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,615 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,616 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,617 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,617 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,618 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:41,620 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,621 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,622 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,623 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,624 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,625 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,626 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:09:41,627 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-21 17:09:41,628 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,628 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,630 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,632 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,633 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,634 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,635 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,635 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,637 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,638 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,639 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,640 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,641 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,642 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,643 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,643 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,645 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,646 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,646 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,647 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,648 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,649 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,649 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,650 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,651 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,652 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,653 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,655 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,656 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:41,657 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,658 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,659 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,659 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,660 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,661 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,662 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:09:41,663 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-21 17:09:41,664 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,682 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,677 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,699 model.rs:304 executing 2: CONST
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,695 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,703 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,704 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,706 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,706 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,713 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# INFO ezkl.graph 2023-07-21 17:09:41,718 mod.rs:765 setting bits to: 6, setting logrows to: 15
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,720 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:41,722 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,723 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,726 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,728 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,729 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,730 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,730 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,734 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-21 17:09:41,741 mod.rs:765 setting bits to: 6, setting logrows to: 15
# INFO ezkl.graph.model 2023-07-21 17:09:41,747 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,732 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,754 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,755 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,756 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,763 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,767 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,769 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,770 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,771 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,771 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,772 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,773 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,774 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,775 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,776 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,777 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,778 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,779 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,779 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:41,780 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,781 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,783 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,783 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,790 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,796 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,801 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:09:41,808 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-21 17:09:41,809 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,810 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,812 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,813 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,814 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,815 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,816 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,817 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,818 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,819 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-21 17:09:41,823 mod.rs:765 setting bits to: 6, setting logrows to: 15
# INFO ezkl.graph.model 2023-07-21 17:09:41,825 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,821 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,828 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,829 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,829 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,830 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,831 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,832 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,833 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,833 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,834 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# INFO ezkl.graph 2023-07-21 17:09:41,836 mod.rs:765 setting bits to: 6, setting logrows to: 15
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,838 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# INFO ezkl.graph.model 2023-07-21 17:09:41,839 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,839 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,842 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,842 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,844 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,845 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,845 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,846 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,847 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,847 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,848 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,849 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,849 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,849 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,850 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,851 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,852 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:41,853 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,856 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,857 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,857 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,858 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,859 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,860 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:09:41,861 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-21 17:09:41,863 model.rs:247 ONNX operator set version: 10
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,863 model.rs:304 executing 1: CONV
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,864 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,865 model.rs:304 executing 2: CONST
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,866 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,867 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,867 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,868 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,868 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# INFO ezkl.graph 2023-07-21 17:09:41,869 mod.rs:765 setting bits to: 5, setting logrows to: 15
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,870 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# INFO ezkl.graph.model 2023-07-21 17:09:41,871 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,873 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,873 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,874 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,876 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,876 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,877 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,877 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,878 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,879 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,880 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,899 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,910 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,923 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# INFO ezkl.graph 2023-07-21 17:09:41,885 mod.rs:765 setting bits to: 5, setting logrows to: 15
# INFO ezkl.graph.model 2023-07-21 17:09:41,931 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,930 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,939 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,942 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,943 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,944 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,945 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,946 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,947 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,947 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,948 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,948 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,949 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,949 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,950 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:41,951 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,951 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,952 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,953 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:41,953 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,954 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,956 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 4         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 8         │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 4         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 4         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:09:41,959 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-21 17:09:41,961 model.rs:247 ONNX operator set version: 10
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,961 model.rs:304 executing 1: CONV
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,962 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,963 model.rs:304 executing 2: CONST
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:41,963 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,964 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,965 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,966 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,966 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# INFO ezkl.graph 2023-07-21 17:09:41,968 mod.rs:765 setting bits to: 5, setting logrows to: 15
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,968 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# INFO ezkl.graph.model 2023-07-21 17:09:41,969 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,971 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,972 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,972 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,974 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,975 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,975 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,977 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:41,978 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,979 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# INFO ezkl.graph 2023-07-21 17:09:41,979 mod.rs:765 setting bits to: 5, setting logrows to: 15
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:41,980 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# ...
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,791 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,793 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,794 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,795 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,798 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,798 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,799 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,799 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,800 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,800 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,801 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,804 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:48,806 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,821 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,824 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,828 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,829 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,830 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,830 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 11        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 22        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 11        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 11        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:09:48,831 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_onnx.model 2023-07-21 17:09:48,832 model.rs:247 ONNX operator set version: 10
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,833 model.rs:304 executing 1: CONV
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:48,833 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,840 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,873 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,880 model.rs:349 model outputs are nodes: [3]
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:48,870 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,883 model.rs:304 executing 1: CONV
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,884 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,885 model.rs:304 executing 2: CONST
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,886 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,887 model.rs:304 executing 3: RELU
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,893 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,895 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-21 17:09:48,897 mod.rs:765 setting bits to: 20, setting logrows to: 21
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,896 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:48,898 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,899 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,899 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,906 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,908 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,909 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-21 17:09:48,911 mod.rs:765 setting bits to: 20, setting logrows to: 21
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,903 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# INFO ezkl.graph.model 2023-07-21 17:09:48,914 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,914 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,916 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,925 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,928 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,931 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,932 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,936 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,939 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,942 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,945 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,947 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,950 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,952 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,954 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,955 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,957 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,959 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,959 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,960 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:48,961 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:48,963 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,964 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,966 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,967 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:48,967 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,968 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,970 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 11        │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 22        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 11        │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 11        │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph.model 2023-07-21 17:09:48,971 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,975 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,975 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,976 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,976 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,978 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,979 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,982 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,981 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,983 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,985 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,986 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,987 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,987 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,989 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,990 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-21 17:09:48,990 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-21 17:09:48,991 mod.rs:765 setting bits to: 20, setting logrows to: 21
# INFO ezkl.graph.model 2023-07-21 17:09:49,000 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,005 model.rs:304 executing 1: CONV
# INFO ezkl.graph 2023-07-21 17:09:48,992 mod.rs:765 setting bits to: 21, setting logrows to: 22
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,007 model.rs:304 executing 2: CONST
# INFO ezkl.graph.model 2023-07-21 17:09:49,010 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,011 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,014 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,017 model.rs:349 model outputs are nodes: [3]
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,019 model.rs:304 executing 2: CONST
# INFO ezkl.graph 2023-07-21 17:09:49,019 mod.rs:765 setting bits to: 20, setting logrows to: 21
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,020 model.rs:304 executing 3: RELU
# INFO ezkl.graph.model 2023-07-21 17:09:49,021 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG ezkl.graph.model 2023-07-21 17:09:49,022 model.rs:349 model outputs are nodes: [3]
# INFO ezkl.graph 2023-07-21 17:09:49,023 mod.rs:765 setting bits to: 21, setting logrows to: 22
# INFO ezkl.graph.model 2023-07-21 17:09:49,024 model.rs:246 model generates 8748 constraints (excluding modules)
# DEBUG ezkl.execute 2023-07-21 17:09:49,025 execute.rs:721 Found 8 sets of parameters
# DEBUG ezkl.execute 2023-07-21 17:09:49,026 execute.rs:757 Saved parameters.

# %% [markdown]
# As we use Halo2 with KZG-commitments we need an SRS string from (preferably) a multi-party trusted setup ceremony. For an overview of the procedures for such a ceremony check out [this page](https://blog.ethereum.org/2023/01/16/announcing-kzg-ceremony). The `get_srs` command retrieves a correctly sized SRS given the calibrated settings file from [here](https://github.com/han0110/halo2-kzg-srs).
#
# These SRS were generated with [this](https://github.com/privacy-scaling-explorations/perpetualpowersoftau) ceremony.

# %%
res = ezkl.get_srs(srs_path, settings_path)
# Out:
# DEBUG reqwest.connect 2023-07-21 17:07:42,045 connect.rs:429 starting new connection: https://trusted-setup-halo2kzg.s3.eu-central-1.amazonaws.com/
# INFO ezkl.execute 2023-07-21 17:07:45,158 execute.rs:502 SRS downloaded

# %% [markdown]
# We now need to generate the (partial) circuit witness. These are the model outputs (and any hashes) that are generated when feeding the previously generated `input.json` through the circuit / model.

# %%
# !export RUST_BACKTRACE=1

witness_path = "witness.json"

res = ezkl.gen_witness(data_path, model_path, witness_path, settings_path = settings_path)
# Out:
# DEBUG tract_onnx.model 2023-07-21 17:09:24,770 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:24,772 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:24,772 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,773 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,773 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,774 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,774 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,775 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,775 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,775 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,776 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,776 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,776 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,777 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,777 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,777 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,778 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,778 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,778 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,778 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,779 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,779 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,779 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,780 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,780 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,780 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,781 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,781 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:24,781 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:24,782 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:24,782 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:24,783 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:24,783 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:24,784 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:24,784 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:24,784 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 7         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 14        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 7         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 7         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# DEBUG ezkl.graph.model 2023-07-21 17:09:24,799 model.rs:304 executing 1: CONV
# DEBUG ezkl.graph.model 2023-07-21 17:09:24,799 model.rs:304 executing 2: CONST
# DEBUG ezkl.graph.model 2023-07-21 17:09:24,800 model.rs:304 executing 3: RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:24,800 model.rs:349 model outputs are nodes: [3]

# %% [markdown]
# As a sanity check you can "mock prove" (i.e check that all the constraints of the circuit match without generate a full proof).

# %%
res = ezkl.mock(witness_path, model_path, settings_path)
# Out:
# DEBUG tract_onnx.model 2023-07-21 17:09:27,436 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:27,438 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:09:27,439 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,439 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,440 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,440 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,440 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,441 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,441 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,442 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,442 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,443 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,443 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,443 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,444 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,444 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,445 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,445 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,446 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,446 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,446 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,447 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,447 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,447 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,448 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,449 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,449 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,449 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:09:27,450 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:09:27,450 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:27,450 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:27,451 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:27,451 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:09:27,452 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,453 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,454 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 7         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 14        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 7         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 7         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph 2023-07-21 17:09:27,456 mod.rs:560 public inputs lengths: [1]
# INFO ezkl.execute 2023-07-21 17:09:27,457 execute.rs:777 Mock proof
# INFO ezkl.graph.model 2023-07-21 17:09:27,458 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:09:27,458 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:09:27,459 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-21 17:09:27,878 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:09:27,879 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,944 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,944 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,945 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,945 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,945 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:09:27,946 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,946 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,948 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,949 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,949 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:09:27,949 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:09:27,950 model.rs:666 computing...

# %% [markdown]
# Here we setup verifying and proving keys for the circuit. As the name suggests the proving key is needed for ... proving and the verifying key is needed for ... verifying.

# %%
# HERE WE SETUP THE CIRCUIT PARAMS
# WE GOT KEYS
# WE GOT CIRCUIT PARAMETERS
# EVERYTHING ANYONE HAS EVER NEEDED FOR ZK
res = ezkl.setup(
        model_path,
        vk_path,
        pk_path,
        srs_path,
        settings_path,
    )

assert res == True
assert os.path.isfile(vk_path)
assert os.path.isfile(pk_path)
assert os.path.isfile(settings_path)
# Out:
# DEBUG tract_onnx.model 2023-07-21 17:07:46,247 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:07:46,249 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:07:46,250 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,250 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,251 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,251 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,251 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,251 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,252 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,252 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,253 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,253 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,253 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,253 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,254 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,254 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,254 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,254 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,254 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,255 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,255 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,255 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,255 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,256 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,256 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,257 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,257 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,257 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:46,258 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:07:46,258 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:46,258 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:46,259 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:46,259 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:46,260 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,260 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,260 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 7         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 14        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 7         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 7         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.pfsys.srs 2023-07-21 17:07:46,261 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-21 17:07:46,264 execute.rs:1634 downsizing params to 15 logrows
# INFO ezkl.graph.model 2023-07-21 17:07:46,265 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:46,265 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:46,265 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-21 17:07:46,290 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:46,291 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,306 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,307 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,307 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,308 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,308 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:07:46,309 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,309 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,310 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,311 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,311 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:46,311 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:07:46,312 model.rs:666 computing...
# INFO ezkl.pfsys 2023-07-21 17:07:48,035 mod.rs:369 VK took 1.769
# INFO ezkl.graph.model 2023-07-21 17:07:48,035 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:48,036 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:48,037 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-21 17:07:48,061 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:48,062 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,077 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,080 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,082 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,082 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,083 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:07:48,084 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,084 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,085 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,087 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,088 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:48,088 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:07:48,088 model.rs:666 computing...
# INFO ezkl.pfsys 2023-07-21 17:07:49,588 mod.rs:375 PK took 1.552
# INFO ezkl.pfsys 2023-07-21 17:07:49,589 mod.rs:556 saving verification key 💾
# INFO ezkl.pfsys 2023-07-21 17:07:49,591 mod.rs:539 saving proving key 💾

# %% [markdown]
# Now we generate a full proof.

# %%
# GENERATE A PROOF

proof_path = os.path.join('test.pf')

res = ezkl.prove(
        witness_path,
        model_path,
        pk_path,
        proof_path,
        srs_path,
        "evm",
        "single",
        settings_path,
    )

print(res)
assert os.path.isfile(proof_path)
# Out:
# DEBUG tract_onnx.model 2023-07-21 17:07:49,827 model.rs:247 ONNX operator set version: 10
# DEBUG tract_hir.infer.analyser 2023-07-21 17:07:49,829 analyser.rs:151   Refined 3/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_hir.infer.analyser 2023-07-21 17:07:49,837 analyser.rs:151   Refined 4/0>: ..,? -> 1,1,1,1,F32
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,847 change_axes.rs:76   Considering change AxisChange { outlet: 0/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,848 change_axes.rs:88     Change AxisChange { outlet: 0/0>, op: Rm(0) } blocked by locked interface 0/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,848 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,849 change_axes.rs:88     Change AxisChange { outlet: 1/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,850 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,851 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(1) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,851 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,853 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(2) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,854 change_axes.rs:76   Considering change AxisChange { outlet: 1/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,855 change_axes.rs:116     Propagation of AxisChange { outlet: 1/0>, op: Rm(3) } blocked by #1 "/conv1/Conv" ConvUnary
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,856 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,857 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,858 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,859 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,859 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,860 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,864 change_axes.rs:76   Considering change AxisChange { outlet: 2/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,866 change_axes.rs:88     Change AxisChange { outlet: 2/0>, op: Rm(3) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,867 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(0) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,868 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(0) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,868 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(1) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,869 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(1) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,872 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(2) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,874 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(2) } blocked by locked interface 3/0>
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,875 change_axes.rs:76   Considering change AxisChange { outlet: 3/0>, op: Rm(3) }
# DEBUG tract_core.optim.change_axes 2023-07-21 17:07:49,876 change_axes.rs:88     Change AxisChange { outlet: 3/0>, op: Rm(3) } blocked by locked interface 3/0>
# INFO ezkl.graph.model 2023-07-21 17:07:49,883 model.rs:421 set batch size to 1
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:49,884 utilities.rs:248 Loading node: Node { id: 0, name: "input", inputs: [], op: TypedSource { fact: 1,3,8,8,F32 }, outputs: [1,3,8,8,F32 >1/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:49,886 utilities.rs:248 Loading node: Node { id: 1, name: "/conv1/Conv", inputs: [0/0>], op: ConvUnary { pool_spec: PoolSpec { data_format: NCHW, kernel_shape: [5, 5], padding: Explicit([0, 0], [0, 0], false), dilations: Some([1, 1]), strides: Some([4, 4]), output_channel_override: Some(1) }, kernel_fmt: OIHW, kernel: 1,3,5,5,F32 -0.015037522, 0.0843263, 0.06802663, -0.08973271, -0.054876577, 0.01036036, -0.09775315, 0.03727129, 0.08548531, -0.01974751, -0.05061966, 0.006434068..., group: 1, bias: Some(1,F32 0.06882888), q_params: None }, outputs: [1,1,1,1,F32 >3/0] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:49,887 utilities.rs:248 Loading node: Node { id: 2, name: "/relu/Relu.low.cst", inputs: [], op: Const(1,1,1,1,F32 0), outputs: [1,1,1,1,F32 0 >3/1] }
# DEBUG ezkl.graph.utilities 2023-07-21 17:07:49,892 utilities.rs:248 Loading node: Node { id: 3, name: "/relu/Relu.low", inputs: [1/0>, 2/0>], op: TypedBinOp(Max), outputs: [1,1,1,1,F32 ] }
# DEBUG ezkl.graph.model 2023-07-21 17:07:49,894 model.rs:430
#      0 |                   -> >1/0              | Source                    input                                              [] => [1,3,8,8,F32]
#     1 | 0/0>              -> >3/0              | ConvUnary                 /conv1/Conv                                        [1,3,8,8,F32] => [1,1,1,1,F32]
#                                                |   * output #0: /conv1/Conv_output_0 >3/0
#     2 |                   -> >3/1              | Const                     /relu/Relu.low.cst                                 [] => [1,1,1,1,F32 0]
#     3 | 1/0>     2/0>     ->                   | Max                       /relu/Relu.low                                     [1,1,1,1,F32, 1,1,1,1,F32 0] => [1,1,1,1,F32]
# outputs: 3/0>
#
# DEBUG ezkl.graph.model 2023-07-21 17:07:49,895 model.rs:223
#
# ┌────────┬───────────┬────────┬──────────────┬─────┐
# │ opkind │ out_scale │ inputs │ out_dims     │ idx │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ Input  │ 7         │        │ [1, 3, 8, 8] │ 0   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONV   │ 14        │ [0]    │ [1, 1, 1, 1] │ 1   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ CONST  │ 7         │        │ [1, 1, 1, 1] │ 2   │
# ├────────┼───────────┼────────┼──────────────┼─────┤
# │ RELU   │ 7         │ [1]    │ [1, 1, 1, 1] │ 3   │
# └────────┴───────────┴────────┴──────────────┴─────┘
# INFO ezkl.graph 2023-07-21 17:07:49,900 mod.rs:560 public inputs lengths: [1]
# INFO ezkl.pfsys.srs 2023-07-21 17:07:49,903 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-21 17:07:49,909 execute.rs:1634 downsizing params to 15 logrows
# INFO ezkl.pfsys 2023-07-21 17:07:49,916 mod.rs:519 loading proving key from "test.pk"
# INFO ezkl.graph.model 2023-07-21 17:07:49,921 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:49,924 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:49,931 chip.rs:345 assigning lookup output
# INFO ezkl.pfsys 2023-07-21 17:07:50,200 mod.rs:429 proof started...
# INFO ezkl.graph.model 2023-07-21 17:07:50,203 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:50,204 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:50,205 chip.rs:345 assigning lookup output
# INFO ezkl.graph.model 2023-07-21 17:07:50,619 model.rs:604 model layout...
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:50,623 chip.rs:355 laying out table for RELU
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,642 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,643 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,644 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,644 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,645 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:07:50,645 model.rs:666 computing...
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,645 model.rs:690 laying out 0: Input, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,646 model.rs:690 laying out 1: CONV, offset:0
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,646 model.rs:690 laying out 2: CONST, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,647 model.rs:690 laying out 3: RELU, offset:76
# DEBUG ezkl.graph.model 2023-07-21 17:07:50,647 model.rs:727 model outputs are nodes: [3]
# INFO ezkl.graph.model 2023-07-21 17:07:50,647 model.rs:666 computing...
# INFO ezkl.execute 2023-07-21 17:07:53,964 execute.rs:1177 proof took 3.765
# {'instances': [[[16, 0, 0, 0]], [[4172702715194216444, 4343298861975152182, 16572759352690916491, 998843874258490695], [0, 0, 0, 0]]], 'proof': '...', 'transcript_type': 'EVM'}

# %% [markdown]
# And verify it as a sanity check.

# %%
# VERIFY IT

res = ezkl.verify(
        proof_path,
        settings_path,
        vk_path,
        srs_path,
    )

assert res == True
print("verified")
# Out:
# INFO ezkl.pfsys.srs 2023-07-21 17:07:53,983 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-21 17:07:53,987 execute.rs:1634 downsizing params to 15 logrows
# INFO ezkl.pfsys 2023-07-21 17:07:53,988 mod.rs:498 loading verification key from "test.vk"
# INFO ezkl.graph.model 2023-07-21 17:07:53,989 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:53,990 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:53,990 chip.rs:345 assigning lookup output
# INFO ezkl.execute 2023-07-21 17:07:54,002 execute.rs:1593 verify took 0.5
# INFO ezkl.execute 2023-07-21 17:07:54,003 execute.rs:1598 verified: true
# verified

# %% [markdown]
# We can now create an EVM / `.sol` verifier that can be deployed on chain to verify submitted proofs using a view function.

# %%
abi_path = 'test.abi'
sol_code_path = 'test.sol'

res = ezkl.create_evm_verifier(
        vk_path,
        srs_path,
        settings_path,
        sol_code_path,
        abi_path,
    )
assert res == True
# Out:
# INFO ezkl.execute 2023-07-21 17:07:54,009 execute.rs:80 checking solc installation..
# DEBUG ezkl.execute 2023-07-21 17:07:54,044 execute.rs:84 solc output: Output {
#     status: ExitStatus(
#         unix_wait_status(
#             0,
#         ),
#     ),
#     stdout: "solc, the solidity compiler commandline interface\nVersion: 0.8.20+commit.a1b79de6.Darwin.appleclang\n",
#     stderr: "",
# }
# DEBUG ezkl.execute 2023-07-21 17:07:54,045 execute.rs:86 solc output success: true
# DEBUG ezkl.execute 2023-07-21 17:07:54,045 execute.rs:93 solc check passed, proceeding
# INFO ezkl.pfsys.srs 2023-07-21 17:07:54,046 srs.rs:23 loading srs from "kzg.srs"
# INFO ezkl.execute 2023-07-21 17:07:54,051 execute.rs:1634 downsizing params to 15 logrows
# INFO ezkl.pfsys 2023-07-21 17:07:54,053 mod.rs:498 loading verification key from "test.vk"
# INFO ezkl.graph.model 2023-07-21 17:07:54,053 model.rs:572 configuring model
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:54,053 chip.rs:341 assigning lookup input
# DEBUG ezkl.circuit.ops.chip 2023-07-21 17:07:54,054 chip.rs:345 assigning lookup output

# %% [markdown]
# ## Verify on the evm

# %%
# Make sure anvil is running locally first
# run with $ anvil -p 3030
# we use the default anvil node here
import json

address_path = os.path.join("address.json")

res = ezkl.deploy_evm(
    address_path,
    sol_code_path,
    'http://127.0.0.1:3030'
)

assert res == True

with open(address_path, 'r') as file:
    addr = file.read().rstrip()
# Out:
# INFO ezkl.execute 2023-07-21 17:07:54,406 execute.rs:80 checking solc installation..
# DEBUG reqwest.connect 2023-07-21 17:07:54,461 connect.rs:429 starting new connection: http://127.0.0.1:3030/
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 8
#       4 import json
#       6 address_path = os.path.join("address.json")
# ----> 8 res = ezkl.deploy_evm(
#       9     address_path,
#      10     sol_code_path,
#      11     'http://127.0.0.1:3030'
#      12 )
#      14 assert res == True
#      16 with open(address_path, 'r') as file:
#
# RuntimeError: Failed to run deploy_evm: error sending request for url (http://127.0.0.1:3030/): error trying to connect: tcp connect error: Connection refused (os error 61)

# %%
# make sure anvil is running locally
# $ anvil -p 3030

res = ezkl.verify_evm(
    proof_path,
    addr,
    "http://127.0.0.1:3030"
)
assert res == True
